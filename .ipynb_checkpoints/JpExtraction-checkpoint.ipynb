# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

def downloader(pdf_address='C:\\Users\\user1\\Documents\\Paper\\Chachuat_07(IC32).pdf'): #C:\\Users\\user1\\Documents\\Japanese\\J1-100.pdf
    """
    To download Portugal imbalance data.
    Args:
        start_date (str): start date of download, in yyyy-mm-dd
        end_date (str): end date of download, in yyyy-mm-dd
        
    """
    
#     with webdriver.Chrome() as driver:
    driver = webdriver.Chrome()
    driver.get('https://www.newocr.com/')

    pdf_selector = driver.find_element_by_name('userfile')
    pdf_selector.send_keys(pdf_address)
    driver.find_element_by_id('preview').click()
    
    driver.find_element_by_class_name('search-field').click()
    language_list = driver.find_elements_by_tag_name('li')
    language_list[58].click() # 58 is japanese
    
    driver.find_element_by_name('ocr')
    
    driver.find_element_by_class_name('dropdown-toggle').click()
    dl_dropdown = driver.find_element_by_class_name('dropdown-menu')
    dl_dropdown.find_element_by_tag_name('li').click()

# %%
downloader()
